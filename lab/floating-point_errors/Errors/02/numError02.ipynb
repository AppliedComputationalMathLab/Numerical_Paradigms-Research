# %%
#!python -m ensurepip --upgrade

# %%
#pip install numpy
#pip install matplotlib
#pip install seaborn
#pip install ipython
#pip install --upgrade nbformat
#pip install plotly
#!pip install pandas

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px
import pandas as pd 
import plotly.express as px
import numpy as np
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.io as pio
import plotly.subplots as sp
import plotly.express as px

# %%
def f(x: np.float64) -> np.float64:
    return (x - 1)**6

def q(x: np.float64) -> np.float64:
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
rangeAn = [1.0035,1.006]

# %%
x1 = np.linspace(rangeAn[0], rangeAn[1], 2500, dtype=np.float64)
y1 = f(x1)

x2 = np.linspace(rangeAn[0], rangeAn[1], 2500, dtype=np.float64)
y2 = q(x2)

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

plt.plot(x2, y2, label='q(x) = x^6 - 6x^5 + 15x^4 - 20x^3 + 15x^2 - 6x + 1', color="#FFA600FF")
plt.plot(x1, y1, label='p(x) = (x-1)^6', color="#1100FFFF")
plt.xlim(rangeAn)

plt.xlabel('x')
plt.legend(fontsize=15)

centimeters_x = 27
centimeters_y = 11.5

inches_x = centimeters_x / 2.54
inches_y = centimeters_y / 2.54


plt.gcf().set_size_inches(inches_x, inches_y)

plt.grid(True, linewidth=1.0, alpha=1)

plt.savefig(
    "graphs/poster/NumError2_mplt.pdf",
    format='pdf',
    bbox_inches='tight',
)

# %%
fig = px.scatter()
fig.add_scatter(x=x2, y=y2, mode='lines', name='q(x)')
fig.add_scatter(x=x1, y=y1, mode='lines', name='p(x)')
fig.show()
