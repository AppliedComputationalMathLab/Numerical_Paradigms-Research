# %%
#!python -m ensurepip --upgrade

# %%
#pip install numpy
#pip install matplotlib
#pip install seaborn
#pip install ipython
#pip install --upgrade nbformat
#pip install plotly
#!pip install pandas

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pandas as pd 
import plotly.express as px
import numpy as np
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.io as pio
import plotly.subplots as sp
import plotly.express as px

# %%
def f(x: np.float64) -> np.float64:
    return (x - 2)**9

def e(x: np.float64) -> np.float64:
    return x**9 - 18*x**8 + 144*x**7 - 672*x**6 + 2016*x**5 - 4032*x**4 + 5376*x**3 - 4608*x**2 + 2304*x - 512

# %%
rangeX = (1.9999,2.0001)
rangeY = (-3e-11, 3e-11)

# %%
x1 = np.linspace(rangeX[0], rangeX[1], 10000, dtype=np.float64)
y1 = f(x1)

x2 = np.linspace(rangeX[0], rangeX[1], 10000, dtype=np.float64)
y2 = e(x2)

# %%
plt.plot(x2, y2, label='expanded', color="#FFA600FF", linewidth=0.5)
plt.plot(x1, y1, label='factored', color="#1100FFFF", linewidth=1)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.gcf().set_size_inches(18, 6)
plt.legend(fontsize=18)
plt.xlim(rangeX)
plt.ylim(rangeY)
plt.grid(True)
